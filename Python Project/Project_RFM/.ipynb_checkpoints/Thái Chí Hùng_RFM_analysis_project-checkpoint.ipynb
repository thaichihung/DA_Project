# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import xlrd

# %% [markdown]
# # Task 1: Preparing Dataset

# %%
xls = pd.ExcelFile('Dataset.xlsx')
df = pd.read_excel(xls, 'Orders')
df.head()
# Out:
#    Row ID        Order ID  Order Date  Ship Date       Ship Mode Customer ID  \
# 0     646  CA-2017-126221       43099      43105  Standard Class    CC-12430
# 1     907  CA-2017-143259       43099      43103  Standard Class    PO-18865
# 2     908  CA-2017-143259       43099      43103  Standard Class    PO-18865
# 3     909  CA-2017-143259       43099      43103  Standard Class    PO-18865
# 4    1297  CA-2017-115427       43099      43103  Standard Class    EB-13975
#
#        Channel  Postal Code       Product ID    Sales  Quantity  Unit Price  \
# 0  Home Office        47201  OFF-AP-10002457  209.300         2     76.3945
# 1     Consumer        10009  FUR-BO-10003441  323.136         4     77.7546
# 2     Consumer        10009  TEC-PH-10004774   90.930         7     12.6003
# 3     Consumer        10009  OFF-BI-10003684   52.776         3     10.9950
# 4    Corporate        94533  OFF-BI-10002103   13.904         2      4.6926
#
#    Discount   Profit
# 0       0.0  56.5110
# 1       0.2  12.1176
# 2       0.0   2.7279
# 3       0.2  19.7910
# 4       0.2   4.5188

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Row ID       9994 non-null   int64
#  1   Order ID     9994 non-null   object
#  2   Order Date   9994 non-null   int64
#  3   Ship Date    9994 non-null   int64
#  4   Ship Mode    9994 non-null   object
#  5   Customer ID  9994 non-null   object
#  6   Channel      9994 non-null   object
#  7   Postal Code  9994 non-null   int64
#  8   Product ID   9994 non-null   object
#  9   Sales        9994 non-null   float64
#  10  Quantity     9994 non-null   int64
#  11  Unit Price   9994 non-null   float64
#  12  Discount     9994 non-null   float64
#  13  Profit       9994 non-null   float64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 1.1+ MB

# %%
df['Order Date'] = df['Order Date'].apply(lambda x: xlrd.xldate_as_datetime(x, 0))
df['Ship Date'] = df['Ship Date'].apply(lambda x: xlrd.xldate_as_datetime(x, 0))

# %%
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0        646  CA-2017-126221 2017-12-30 2018-01-05  Standard Class
# 1        907  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 2        908  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 3        909  CA-2017-143259 2017-12-30 2018-01-03  Standard Class
# 4       1297  CA-2017-115427 2017-12-30 2018-01-03  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    1760  CA-2014-141817 2014-01-05 2014-01-12  Standard Class
# 9990     740  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9991     741  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9992     742  CA-2014-112326 2014-01-04 2014-01-08  Standard Class
# 9993    7981  CA-2014-103800 2014-01-03 2014-01-07  Standard Class
#
#      Customer ID      Channel  Postal Code       Product ID    Sales  \
# 0       CC-12430  Home Office        47201  OFF-AP-10002457  209.300
# 1       PO-18865     Consumer        10009  FUR-BO-10003441  323.136
# 2       PO-18865     Consumer        10009  TEC-PH-10004774   90.930
# 3       PO-18865     Consumer        10009  OFF-BI-10003684   52.776
# 4       EB-13975    Corporate        94533  OFF-BI-10002103   13.904
# ...          ...          ...          ...              ...      ...
# 9989    MB-18085     Consumer        19143  OFF-AR-10003478   19.536
# 9990    PO-19195  Home Office        60540  OFF-LA-10003223   11.784
# 9991    PO-19195  Home Office        60540  OFF-ST-10002743  272.736
# 9992    PO-19195  Home Office        60540  OFF-BI-10004094    3.540
# 9993    DP-13000     Consumer        77095  OFF-PA-10000174   16.448
#
#       Quantity  Unit Price  Discount   Profit
# 0            2     76.3945       0.0  56.5110
# 1            4     77.7546       0.2  12.1176
# 2            7     12.6003       0.0   2.7279
# 3            3     10.9950       0.2  19.7910
# 4            2      4.6926       0.2   4.5188
# ...        ...         ...       ...      ...
# 9989         3      4.8840       0.2   4.8840
# 9990         3      2.5041       0.2   4.2717
# 9991         3    112.5036       0.2 -64.7748
# 9992         2      4.5135       0.8  -5.4870
# 9993         2      5.4484       0.2   5.5512
#
# [9994 rows x 14 columns]

# %% [markdown]
# # Task 2: Calculate R, F, M index

# %% [markdown]
# ## Task 2.1: Calculate R index

# %%
df_r = df.groupby('Customer ID')['Order Date'].max().reset_index()
df_r
# Out:
#     Customer ID Order Date
# 0      AA-10315 2017-06-29
# 1      AA-10375 2017-12-11
# 2      AA-10480 2017-04-15
# 3      AA-10645 2017-11-05
# 4      AB-10015 2016-11-10
# ..          ...        ...
# 788    XP-21865 2017-11-17
# 789    YC-21895 2017-12-26
# 790    YS-21880 2017-12-21
# 791    ZC-21910 2017-11-06
# 792    ZD-21925 2017-06-11
#
# [793 rows x 2 columns]

# %%
df_r['r_index'] = df_r['Order Date'].max()-df_r['Order Date']
df_r.columns = ['Customer ID', 'MaxPurchaseDate', 'Recency']
df_r
# Out:
#     Customer ID MaxPurchaseDate  Recency
# 0      AA-10315      2017-06-29 184 days
# 1      AA-10375      2017-12-11  19 days
# 2      AA-10480      2017-04-15 259 days
# 3      AA-10645      2017-11-05  55 days
# 4      AB-10015      2016-11-10 415 days
# ..          ...             ...      ...
# 788    XP-21865      2017-11-17  43 days
# 789    YC-21895      2017-12-26   4 days
# 790    YS-21880      2017-12-21   9 days
# 791    ZC-21910      2017-11-06  54 days
# 792    ZD-21925      2017-06-11 202 days
#
# [793 rows x 3 columns]

# %%
df_customer = df_r[['Customer ID', 'Recency']]

# %% [markdown]
# ## Task 2.2: Calculate F index

# %%
df_f = df.groupby('Customer ID')['Order ID'].count().reset_index()
df_f.columns = ['Customer ID', 'Frequency']

# %%
df_customer = pd.merge(df_customer, df_f, on='Customer ID')
df_customer
# Out:
#     Customer ID  Recency  Frequency
# 0      AA-10315 184 days         11
# 1      AA-10375  19 days         15
# 2      AA-10480 259 days         12
# 3      AA-10645  55 days         18
# 4      AB-10015 415 days          6
# ..          ...      ...        ...
# 788    XP-21865  43 days         28
# 789    YC-21895   4 days          8
# 790    YS-21880   9 days         12
# 791    ZC-21910  54 days         31
# 792    ZD-21925 202 days          9
#
# [793 rows x 3 columns]

# %% [markdown]
# ## Task 2.3: Calculate M index

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     646  CA-2017-126221 2017-12-30 2018-01-05  Standard Class    CC-12430
# 1     907  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 2     908  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 3     909  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 4    1297  CA-2017-115427 2017-12-30 2018-01-03  Standard Class    EB-13975
#
#        Channel  Postal Code       Product ID    Sales  Quantity  Unit Price  \
# 0  Home Office        47201  OFF-AP-10002457  209.300         2     76.3945
# 1     Consumer        10009  FUR-BO-10003441  323.136         4     77.7546
# 2     Consumer        10009  TEC-PH-10004774   90.930         7     12.6003
# 3     Consumer        10009  OFF-BI-10003684   52.776         3     10.9950
# 4    Corporate        94533  OFF-BI-10002103   13.904         2      4.6926
#
#    Discount   Profit
# 0       0.0  56.5110
# 1       0.2  12.1176
# 2       0.0   2.7279
# 3       0.2  19.7910
# 4       0.2   4.5188

# %%
df['Revenue'] = df['Quantity']*df['Unit Price']

# %%
df_m = df.groupby('Customer ID')['Revenue'].sum().reset_index()
df_m.columns = ['Customer ID', 'Monetary']

# %%
df_customer = pd.merge(df_customer, df_m, on='Customer ID')
df_customer
# Out:
#     Customer ID  Recency  Frequency   Monetary
# 0      AA-10315 184 days         11  5926.4425
# 1      AA-10375  19 days         15   779.0076
# 2      AA-10480 259 days         12  1354.6846
# 3      AA-10645  55 days         18  4229.1317
# 4      AB-10015 415 days          6   756.8095
# ..          ...      ...        ...        ...
# 788    XP-21865  43 days         28  1753.4280
# 789    YC-21895   4 days          8  4148.7210
# 790    YS-21880   9 days         12  4942.1517
# 791    ZC-21910  54 days         31  9057.8560
# 792    ZD-21925 202 days          9  1244.8133
#
# [793 rows x 4 columns]

# %% [markdown]
# # Task 3: Ranking each index from 1-5

# %% [markdown]
# ## Task 3.1: Ranking R index

# %%
df_customer['Recency'] = -df_customer['Recency']

# %%
bins = ['1', '2', '3', '4', '5']
df_customer['Recency rank'] = pd.qcut(df_customer['Recency'],q = 5, labels = bins)
df_customer
# Out:
#     Customer ID   Recency  Frequency   Monetary Recency rank
# 0      AA-10315 -184 days         11  5926.4425            2
# 1      AA-10375  -19 days         15   779.0076            5
# 2      AA-10480 -259 days         12  1354.6846            1
# 3      AA-10645  -55 days         18  4229.1317            3
# 4      AB-10015 -415 days          6   756.8095            1
# ..          ...       ...        ...        ...          ...
# 788    XP-21865  -43 days         28  1753.4280            4
# 789    YC-21895   -4 days          8  4148.7210            5
# 790    YS-21880   -9 days         12  4942.1517            5
# 791    ZC-21910  -54 days         31  9057.8560            3
# 792    ZD-21925 -202 days          9  1244.8133            2
#
# [793 rows x 5 columns]

# %%
df_customer.describe()
# Out:
#                              Recency   Frequency      Monetary
# count                            793  793.000000    793.000000
# mean   -147 days +04:45:05.674653216   12.602774   2535.692104
# std      186 days 05:03:54.791539520    6.242559   2308.469645
# min             -1165 days +00:00:00    1.000000      4.839900
# 25%              -183 days +00:00:00    8.000000   1061.324100
# 50%               -75 days +00:00:00   12.000000   1964.578900
# 75%               -30 days +00:00:00   16.000000   3269.070500
# max                  0 days 00:00:00   37.000000  27023.789300

# %% [markdown]
# ## Task 3.2: Ranking F index

# %%
df_customer['Frequency rank'] = pd.qcut(df_customer['Frequency'],q = 5, labels = bins)
df_customer
# Out:
#     Customer ID   Recency  Frequency   Monetary Recency rank Frequency rank
# 0      AA-10315 -184 days         11  5926.4425            2              3
# 1      AA-10375  -19 days         15   779.0076            5              4
# 2      AA-10480 -259 days         12  1354.6846            1              3
# 3      AA-10645  -55 days         18  4229.1317            3              4
# 4      AB-10015 -415 days          6   756.8095            1              1
# ..          ...       ...        ...        ...          ...            ...
# 788    XP-21865  -43 days         28  1753.4280            4              5
# 789    YC-21895   -4 days          8  4148.7210            5              2
# 790    YS-21880   -9 days         12  4942.1517            5              3
# 791    ZC-21910  -54 days         31  9057.8560            3              5
# 792    ZD-21925 -202 days          9  1244.8133            2              2
#
# [793 rows x 6 columns]

# %% [markdown]
# ## Task 3.3: Ranking M index

# %%
df_customer['Monetary rank'] = pd.qcut(df_customer['Monetary'],q = 5, labels = bins)
df_customer
# Out:
#     Customer ID   Recency  Frequency   Monetary Recency rank Frequency rank  \
# 0      AA-10315 -184 days         11  5926.4425            2              3
# 1      AA-10375  -19 days         15   779.0076            5              4
# 2      AA-10480 -259 days         12  1354.6846            1              3
# 3      AA-10645  -55 days         18  4229.1317            3              4
# 4      AB-10015 -415 days          6   756.8095            1              1
# ..          ...       ...        ...        ...          ...            ...
# 788    XP-21865  -43 days         28  1753.4280            4              5
# 789    YC-21895   -4 days          8  4148.7210            5              2
# 790    YS-21880   -9 days         12  4942.1517            5              3
# 791    ZC-21910  -54 days         31  9057.8560            3              5
# 792    ZD-21925 -202 days          9  1244.8133            2              2
#
#     Monetary rank
# 0               5
# 1               1
# 2               2
# 3               5
# 4               1
# ..            ...
# 788             3
# 789             5
# 790             5
# 791             5
# 792             2
#
# [793 rows x 7 columns]

# %% [markdown]
# # Task 4: Classify customer

# %%
df_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 793 entries, 0 to 792
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     793 non-null    object
#  1   Recency         793 non-null    timedelta64[ns]
#  2   Frequency       793 non-null    int64
#  3   Monetary        793 non-null    float64
#  4   Recency rank    793 non-null    category
#  5   Frequency rank  793 non-null    category
#  6   Monetary rank   793 non-null    category
# dtypes: category(3), float64(1), int64(1), object(1), timedelta64[ns](1)
# memory usage: 33.9+ KB

# %%
df_customer['Recency rank'] = df_customer['Recency rank'].astype(str)
df_customer['Frequency rank'] = df_customer['Frequency rank'].astype(str)
df_customer['Monetary rank'] = df_customer['Monetary rank'].astype(str)
df_customer['RFM_rank_combine'] = df_customer['Recency rank'] + df_customer['Frequency rank'] + df_customer['Monetary rank']
df_customer.head()
# Out:
#   Customer ID   Recency  Frequency   Monetary Recency rank Frequency rank  \
# 0    AA-10315 -184 days         11  5926.4425            2              3
# 1    AA-10375  -19 days         15   779.0076            5              4
# 2    AA-10480 -259 days         12  1354.6846            1              3
# 3    AA-10645  -55 days         18  4229.1317            3              4
# 4    AB-10015 -415 days          6   756.8095            1              1
#
#   Monetary rank RFM_rank_combine
# 0             5              235
# 1             1              541
# 2             2              132
# 3             5              345
# 4             1              111

# %%
df_customer['RFM_rank_combine'] = pd.to_numeric(df_customer['RFM_rank_combine'])

# %%
df_customer['Customer_Segment']=''
df_customer
# Out:
#     Customer ID   Recency  Frequency   Monetary Recency rank Frequency rank  \
# 0      AA-10315 -184 days         11  5926.4425            2              3
# 1      AA-10375  -19 days         15   779.0076            5              4
# 2      AA-10480 -259 days         12  1354.6846            1              3
# 3      AA-10645  -55 days         18  4229.1317            3              4
# 4      AB-10015 -415 days          6   756.8095            1              1
# ..          ...       ...        ...        ...          ...            ...
# 788    XP-21865  -43 days         28  1753.4280            4              5
# 789    YC-21895   -4 days          8  4148.7210            5              2
# 790    YS-21880   -9 days         12  4942.1517            5              3
# 791    ZC-21910  -54 days         31  9057.8560            3              5
# 792    ZD-21925 -202 days          9  1244.8133            2              2
#
#     Monetary rank  RFM_rank_combine Customer_Segment
# 0               5               235
# 1               1               541
# 2               2               132
# 3               5               345
# 4               1               111
# ..            ...               ...              ...
# 788             3               453
# 789             5               525
# 790             5               535
# 791             5               355
# 792             2               222
#
# [793 rows x 9 columns]

# %%
def segment(rank_combine):
    if rank_combine in [555, 554, 544, 545, 454, 455, 445]:
        return 'Champions'
    elif rank_combine in [543, 444, 435, 355, 354, 345, 344, 335]:
        return 'Loyal'
    elif rank_combine in [553, 551, 552, 541, 542, 533, 532, 531, 452, 451, 442, 441, 431, 453, 433, 432, 423, 353, 352, 351, 342, 341, 333, 323]:
        return 'Potential Loyalist'
    elif rank_combine in [512, 511, 422, 421, 412, 411, 311]:
        return 'New Customers'
    elif rank_combine in [525, 524, 523, 522, 521, 515, 514, 513, 425,424, 413,414,415, 315, 314, 313]:
        return 'Promising'
    elif rank_combine in [535, 534, 443, 434, 343, 334, 325, 324]:
        return 'Need Attention'
    elif rank_combine in [331, 321, 312, 221, 213, 231, 241, 251]:
        return 'About To Sleep'
    elif rank_combine in [255, 254, 245, 244, 253, 252, 243, 242, 235, 234, 225, 224, 153, 152, 145, 143, 142, 135, 134, 133, 125, 124]:
        return 'At Risk'
    elif rank_combine in [155, 154, 144, 214,215,115, 114, 113]:
        return 'Cannot Lose Them'
    elif rank_combine in [332, 322, 233, 232, 223, 222, 132, 123, 122, 212, 211]:
        return 'Hibernating customers'
    elif rank_combine in [111, 112, 121, 131,141,151]:
        return 'Lost customers'

# %%
df_customer['Customer_Segment'] = df_customer['RFM_rank_combine'].map(segment)

# %%
df_customer
# Out:
#     Customer ID   Recency  Frequency   Monetary Recency rank Frequency rank  \
# 0      AA-10315 -184 days         11  5926.4425            2              3
# 1      AA-10375  -19 days         15   779.0076            5              4
# 2      AA-10480 -259 days         12  1354.6846            1              3
# 3      AA-10645  -55 days         18  4229.1317            3              4
# 4      AB-10015 -415 days          6   756.8095            1              1
# ..          ...       ...        ...        ...          ...            ...
# 788    XP-21865  -43 days         28  1753.4280            4              5
# 789    YC-21895   -4 days          8  4148.7210            5              2
# 790    YS-21880   -9 days         12  4942.1517            5              3
# 791    ZC-21910  -54 days         31  9057.8560            3              5
# 792    ZD-21925 -202 days          9  1244.8133            2              2
#
#     Monetary rank  RFM_rank_combine       Customer_Segment
# 0               5               235                At Risk
# 1               1               541     Potential Loyalist
# 2               2               132  Hibernating customers
# 3               5               345                  Loyal
# 4               1               111         Lost customers
# ..            ...               ...                    ...
# 788             3               453     Potential Loyalist
# 789             5               525              Promising
# 790             5               535         Need Attention
# 791             5               355                  Loyal
# 792             2               222  Hibernating customers
#
# [793 rows x 9 columns]

# %% [markdown]
# # Task 5: Visualize Customer Segment with Dimension

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     646  CA-2017-126221 2017-12-30 2018-01-05  Standard Class    CC-12430
# 1     907  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 2     908  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 3     909  CA-2017-143259 2017-12-30 2018-01-03  Standard Class    PO-18865
# 4    1297  CA-2017-115427 2017-12-30 2018-01-03  Standard Class    EB-13975
#
#        Channel  Postal Code       Product ID    Sales  Quantity  Unit Price  \
# 0  Home Office        47201  OFF-AP-10002457  209.300         2     76.3945
# 1     Consumer        10009  FUR-BO-10003441  323.136         4     77.7546
# 2     Consumer        10009  TEC-PH-10004774   90.930         7     12.6003
# 3     Consumer        10009  OFF-BI-10003684   52.776         3     10.9950
# 4    Corporate        94533  OFF-BI-10002103   13.904         2      4.6926
#
#    Discount   Profit   Revenue
# 0       0.0  56.5110  152.7890
# 1       0.2  12.1176  311.0184
# 2       0.0   2.7279   88.2021
# 3       0.2  19.7910   32.9850
# 4       0.2   4.5188    9.3852

# %%
sns.countplot(x = 'Customer_Segment', data = df_customer)
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby('Ship Mode')['Channel'].count()
# Out:
# Ship Mode
# First Class       1538
# Same Day           543
# Second Class      1945
# Standard Class    5968
# Name: Channel, dtype: int64

# %%
df_customer_segment = df_customer[['Customer ID', 'Customer_Segment']]
df_customer_segment
# Out:
#     Customer ID       Customer_Segment
# 0      AA-10315                At Risk
# 1      AA-10375     Potential Loyalist
# 2      AA-10480  Hibernating customers
# 3      AA-10645                  Loyal
# 4      AB-10015         Lost customers
# ..          ...                    ...
# 788    XP-21865     Potential Loyalist
# 789    YC-21895              Promising
# 790    YS-21880         Need Attention
# 791    ZC-21910                  Loyal
# 792    ZD-21925  Hibernating customers
#
# [793 rows x 2 columns]

# %%
df = pd.merge(df, df_customer_segment, on = 'Customer ID')
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0        646  CA-2017-126221 2017-12-30 2018-01-05  Standard Class
# 1       3046  CA-2017-125290 2017-11-06 2017-11-10    Second Class
# 2       3047  CA-2017-125290 2017-11-06 2017-11-10    Second Class
# 3       6372  CA-2017-143035 2017-10-03 2017-10-05    Second Class
# 4       6373  CA-2017-143035 2017-10-03 2017-10-05    Second Class
# ...      ...             ...        ...        ...             ...
# 9989    5393  US-2014-123183 2014-11-19 2014-11-25  Standard Class
# 9990    5394  US-2014-123183 2014-11-19 2014-11-25  Standard Class
# 9991    5395  US-2014-123183 2014-11-19 2014-11-25  Standard Class
# 9992    7665  CA-2014-151967 2014-10-22 2014-10-26  Standard Class
# 9993    2543  CA-2014-164385 2014-09-26 2014-10-01    Second Class
#
#      Customer ID      Channel  Postal Code       Product ID     Sales  \
# 0       CC-12430  Home Office        47201  OFF-AP-10002457   209.300
# 1       CC-12430  Home Office        55407  OFF-AR-10001216    13.900
# 2       CC-12430  Home Office        55407  OFF-PA-10003127    26.380
# 3       CC-12430  Home Office        10009  FUR-FU-10001934    83.920
# 4       CC-12430  Home Office        10009  OFF-AR-10001130     6.630
# ...          ...          ...          ...              ...       ...
# 9989    GR-14560    Corporate        19805  OFF-LA-10001569     9.960
# 9990    GR-14560    Corporate        19805  OFF-BI-10002429   213.080
# 9991    GR-14560    Corporate        19805  FUR-BO-10000362  1025.880
# 9992    NB-18580    Corporate        71111  FUR-FU-10000193   129.920
# 9993    NB-18580    Corporate        19134  OFF-AP-10002191   143.952
#
#       Quantity  Unit Price  Discount    Profit   Revenue    Customer_Segment
# 0            2     76.3945       0.0   56.5110  152.7890  Potential Loyalist
# 1            5      2.0572       0.0    3.6140   10.2860  Potential Loyalist
# 2            1     14.2452       0.0   12.1348   14.2452  Potential Loyalist
# 3            4     15.5252       0.0   21.8192   62.1008  Potential Loyalist
# 4            3      1.1713       0.0    3.1161    3.5139  Potential Loyalist
# ...        ...         ...       ...       ...       ...                 ...
# 9989         2      2.6892       0.0    4.5816    5.3784      Lost customers
# 9990         7     15.8288       0.0  102.2784  110.8016      Lost customers
# 9991         6    131.6546       0.0  235.9524  789.9276      Lost customers
# 9992         4     29.8816       0.0   10.3936  119.5264      Lost customers
# 9993         3     43.1856       0.2   14.3952  129.5568      Lost customers
#
# [9994 rows x 16 columns]

# %% [markdown]
# ## Customer Segment and Revenue

# %%
df_segment_revenue = df[['Customer_Segment', 'Revenue']]
df_segment_revenue = df_segment_revenue.groupby('Customer_Segment')['Revenue'].sum().reset_index()
df_segment_revenue
# Out:
#          Customer_Segment      Revenue
# 0          About To Sleep   37623.8801
# 1                 At Risk  397388.8105
# 2        Cannot Lose Them  100610.5800
# 3               Champions  473487.2224
# 4   Hibernating customers  131773.4894
# 5          Lost customers   42265.7635
# 6                   Loyal  349614.7416
# 7          Need Attention  163470.1029
# 8           New Customers   38584.6578
# 9      Potential Loyalist  165577.9465
# 10              Promising  110406.6439

# %%
sns.catplot(x = 'Customer_Segment', y = 'Revenue', data = df_segment_revenue, kind = 'bar', ci = None)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Customer Segment and Channel

# %%
# Check if each customer have unique channel
df_test = df[['Customer ID', 'Channel']]
df_test = df_test.groupby('Customer ID')['Channel'].nunique().reset_index()
df_test[df_test['Channel']!=1]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Channel]
# Index: []

# %%
df_segment_channel = df[['Customer ID', 'Channel','Customer_Segment']].drop_duplicates()
df_segment_channel = df_segment_channel[['Channel','Customer_Segment']]
df_segment_channel_plot = df_segment_channel.groupby(['Channel','Customer_Segment']).size().reset_index().pivot(columns='Channel', index='Customer_Segment', values=0)
df_segment_channel_plot.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Customer_Segment'>

# %% [markdown]
# ## Customer Segment and Ship Mode

# %%
df_segment_shipmode = df[['Ship Mode','Customer_Segment']]
df_segment_shipmode_plot = df_segment_shipmode.groupby(['Ship Mode','Customer_Segment']).size().reset_index().pivot(columns='Ship Mode', index='Customer_Segment', values=0)
df_segment_shipmode_plot.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Customer_Segment'>

# %%
df_segment_shipmode.groupby('Customer_Segment')['Customer_Segment'].count()
# Out:
# Customer_Segment
# About To Sleep            369
# At Risk                  1755
# Cannot Lose Them          364
# Champions                1948
# Hibernating customers     925
# Lost customers            380
# Loyal                    1433
# Need Attention            634
# New Customers             353
# Potential Loyalist       1465
# Promising                 368
# Name: Customer_Segment, dtype: int64

# %% [markdown]
# ## Customer Segment and Category

# %%
df_product = pd.read_excel(xls, 'Product')
df_product.Category.unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df_product
# Out:
#       Row ID       Product ID         Category Sub-Category  \
# 0          1  FUR-BO-10001798        Furniture    Bookcases
# 1          2  FUR-CH-10000454        Furniture       Chairs
# 2          3  OFF-LA-10000240  Office Supplies       Labels
# 3          4  FUR-TA-10000577        Furniture       Tables
# 4          5  OFF-ST-10000760  Office Supplies      Storage
# ...      ...              ...              ...          ...
# 1889    1890  TEC-PH-10002817       Technology       Phones
# 1890    1891  TEC-MA-10003589       Technology     Machines
# 1891    1892  OFF-AP-10003099  Office Supplies   Appliances
# 1892    1893  TEC-PH-10002645       Technology       Phones
# 1893    1894  OFF-ST-10001627  Office Supplies      Storage
#
#                                            Product Name
# 0                     Bush Somerset Collection Bookcase
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2     Self-Adhesive Address Labels for Typewriters b...
# 3         Bretford CR4500 Series Slim Rectangular Table
# 4                        Eldon Fold 'N Roll Cart System
# ...                                                 ...
# 1889                    RCA ViSYS 25425RE1 Corded phone
# 1890                       Cisco 8961 IP Phone Charcoal
# 1891                        Eureka Hand Vacuum, Bagless
# 1892                                              LG G2
# 1893  Eldon Jumbo ProFile Portable File Boxes Graphi...
#
# [1894 rows x 5 columns]

# %%
df_product_category = df_product[['Product ID', 'Category']]
df_product_category['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df_product_category = df_product_category.groupby('Product ID').agg(lambda x: '/'.join(set(x))).reset_index()
df_product_category
# Out:
#            Product ID    Category
# 0     FUR-BO-10000112   Furniture
# 1     FUR-BO-10000330   Furniture
# 2     FUR-BO-10000362   Furniture
# 3     FUR-BO-10000468   Furniture
# 4     FUR-BO-10000711   Furniture
# ...               ...         ...
# 1857  TEC-PH-10004912  Technology
# 1858  TEC-PH-10004922  Technology
# 1859  TEC-PH-10004924  Technology
# 1860  TEC-PH-10004959  Technology
# 1861  TEC-PH-10004977  Technology
#
# [1862 rows x 2 columns]

# %%
df = pd.merge(df, df_product_category, on = 'Product ID')
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0        646  CA-2017-126221 2017-12-30 2018-01-05  Standard Class
# 1        685  US-2017-168116 2017-11-04 2017-11-04        Same Day
# 2       4615  CA-2016-144540 2016-09-05 2016-09-10  Standard Class
# 3       6985  CA-2016-116526 2016-09-01 2016-09-05  Standard Class
# 4       3638  CA-2016-145177 2016-11-10 2016-11-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    3699  CA-2014-140039 2014-09-13 2014-09-17  Standard Class
# 9990    6582  CA-2016-169887 2016-10-22 2016-10-22        Same Day
# 9991    4909  CA-2014-133809 2014-11-18 2014-11-23    Second Class
# 9992    9563  CA-2016-129280 2016-05-03 2016-05-05     First Class
# 9993    8925  CA-2016-168032 2016-01-30 2016-02-03  Standard Class
#
#      Customer ID      Channel  Postal Code       Product ID     Sales  \
# 0       CC-12430  Home Office        47201  OFF-AP-10002457   209.300
# 1       GT-14635    Corporate        27217  OFF-AP-10002457   167.440
# 2       GH-14410  Home Office        77070  OFF-AP-10002457    62.790
# 3       JA-15970     Consumer        48227  OFF-AP-10002457   376.740
# 4       PP-18955  Home Office        45503  OFF-AP-10002457   334.880
# ...          ...          ...          ...              ...       ...
# 9989    ON-18715    Corporate        85281  OFF-ST-10001034    79.400
# 9990    MS-17530     Consumer        98105  FUR-FU-10003095   101.940
# 9991    MS-17530     Consumer        45014  TEC-PH-10004875     9.588
# 9992    SM-20905     Consumer        43055  TEC-MA-10003589   224.937
# 9993    DF-13135     Consumer        61107  TEC-PH-10004241  1439.968
#
#       Quantity  Unit Price  Discount    Profit    Revenue    Customer_Segment  \
# 0            2     76.3945       0.0   56.5110   152.7890  Potential Loyalist
# 1            2     76.3945       0.2   14.6510   152.7890           Promising
# 2            3     76.3945       0.8 -166.3935   229.1835               Loyal
# 3            4     76.3945       0.1   71.1620   305.5780               Loyal
# 4            4     76.3945       0.2   29.3020   305.5780               Loyal
# ...        ...         ...       ...       ...        ...                 ...
# 9989         5     14.6890       0.2    5.9550    73.4450             At Risk
# 9990         3     23.7860       0.0   30.5820    71.3580      Lost customers
# 9991         2      5.8327       0.4   -2.0774    11.6654      Lost customers
# 9992         3    129.9636       0.7 -164.9538   389.8908      Lost customers
# 9993         4    323.9928       0.2  143.9968  1295.9712    Cannot Lose Them
#
#              Category
# 0     Office Supplies
# 1     Office Supplies
# 2     Office Supplies
# 3     Office Supplies
# 4     Office Supplies
# ...               ...
# 9989  Office Supplies
# 9990        Furniture
# 9991       Technology
# 9992       Technology
# 9993       Technology
#
# [9994 rows x 17 columns]

# %%
df_segment_category = df[['Customer_Segment', 'Category']]
df_segment_category_plot = df_segment_category.groupby(['Customer_Segment', 'Category']).size().reset_index().pivot(columns='Category', index='Customer_Segment', values=0)
df_segment_category_plot.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Customer_Segment'>

# %% [markdown]
# ## Customer Segment and Return

# %%
df_return = pd.read_excel(xls, 'Return')
df_return
# Out:
#     Returned        Order ID
# 0        Yes  CA-2017-153822
# 1        Yes  CA-2017-129707
# 2        Yes  CA-2014-152345
# 3        Yes  CA-2015-156440
# 4        Yes  US-2017-155999
# ..       ...             ...
# 291      Yes  CA-2015-101910
# 292      Yes  CA-2017-156958
# 293      Yes  CA-2016-105585
# 294      Yes  CA-2016-148796
# 295      Yes  CA-2015-149636
#
# [296 rows x 2 columns]

# %%
df = pd.merge(df, df_return, on = 'Order ID', how = 'outer')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9994 entries, 0 to 9993
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID            9994 non-null   int64
#  1   Order ID          9994 non-null   object
#  2   Order Date        9994 non-null   datetime64[ns]
#  3   Ship Date         9994 non-null   datetime64[ns]
#  4   Ship Mode         9994 non-null   object
#  5   Customer ID       9994 non-null   object
#  6   Channel           9994 non-null   object
#  7   Postal Code       9994 non-null   int64
#  8   Product ID        9994 non-null   object
#  9   Sales             9994 non-null   float64
#  10  Quantity          9994 non-null   int64
#  11  Unit Price        9994 non-null   float64
#  12  Discount          9994 non-null   float64
#  13  Profit            9994 non-null   float64
#  14  Revenue           9994 non-null   float64
#  15  Customer_Segment  9994 non-null   object
#  16  Category          9994 non-null   object
#  17  Returned          800 non-null    object
# dtypes: datetime64[ns](2), float64(5), int64(3), object(8)
# memory usage: 1.4+ MB

# %%
df['Returned'] = df['Returned'].fillna('No')
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0        646  CA-2017-126221 2017-12-30 2018-01-05  Standard Class
# 1        685  US-2017-168116 2017-11-04 2017-11-04        Same Day
# 2        684  US-2017-168116 2017-11-04 2017-11-04        Same Day
# 3       4615  CA-2016-144540 2016-09-05 2016-09-10  Standard Class
# 4       4616  CA-2016-144540 2016-09-05 2016-09-10  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    2556  CA-2015-111458 2015-09-26 2015-09-30  Standard Class
# 9990    4551  US-2017-107636 2017-04-30 2017-05-02     First Class
# 9991    1451  US-2015-160150 2015-07-19 2015-07-20     First Class
# 9992    3953  US-2016-151862 2016-03-01 2016-03-08  Standard Class
# 9993    3699  CA-2014-140039 2014-09-13 2014-09-17  Standard Class
#
#      Customer ID      Channel  Postal Code       Product ID     Sales  \
# 0       CC-12430  Home Office        47201  OFF-AP-10002457   209.300
# 1       GT-14635    Corporate        27217  OFF-AP-10002457   167.440
# 2       GT-14635    Corporate        27217  TEC-MA-10004125  7999.980
# 3       GH-14410  Home Office        77070  OFF-AP-10002457    62.790
# 4       GH-14410  Home Office        77070  OFF-FA-10002763    28.440
# ...          ...          ...          ...              ...       ...
# 9989    PF-19165     Consumer        10035  TEC-AC-10001590    50.000
# 9990    NM-18520     Consumer         6040  OFF-LA-10003388     5.760
# 9991    TS-21085     Consumer        85023  OFF-BI-10004352     2.025
# 9992    ON-18715    Corporate        80219  TEC-PH-10003535   159.984
# 9993    ON-18715    Corporate        85281  OFF-ST-10001034    79.400
#
#       Quantity  Unit Price  Discount     Profit     Revenue  \
# 0            2     76.3945       0.0    56.5110    152.7890
# 1            2     76.3945       0.2    14.6510    152.7890
# 2            4   2959.9926       0.5 -3839.9904  11839.9704
# 3            3     76.3945       0.8  -166.3935    229.1835
# 4            9      2.6860       0.2     4.2660     24.1740
# ...        ...         ...       ...        ...         ...
# 9989         2     19.0000       0.0    12.0000     38.0000
# 9990         2      1.4688       0.0     2.8224      2.9376
# 9991         1      3.3750       0.7    -1.3500      3.3750
# 9992         2     72.9927       0.2    13.9986    145.9854
# 9993         5     14.6890       0.2     5.9550     73.4450
#
#         Customer_Segment         Category Returned
# 0     Potential Loyalist  Office Supplies       No
# 1              Promising  Office Supplies       No
# 2              Promising       Technology       No
# 3                  Loyal  Office Supplies       No
# 4                  Loyal  Office Supplies       No
# ...                  ...              ...      ...
# 9989             At Risk       Technology       No
# 9990             At Risk  Office Supplies       No
# 9991      Lost customers  Office Supplies       No
# 9992             At Risk       Technology       No
# 9993             At Risk  Office Supplies       No
#
# [9994 rows x 18 columns]

# %%
df.Returned.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df_segment_returned = df[['Customer_Segment', 'Returned']]
df_segment_returned_plot = df_segment_returned.groupby(['Customer_Segment', 'Returned']).size().reset_index().pivot(columns='Returned', index='Customer_Segment', values=0)
df_segment_returned_plot.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='Customer_Segment'>

# %% [markdown]
# # Task 6: Analyze the current situation of the company and make suggestions for the Marketing team

# %% [markdown]
# - Mặc dù công ty có một số nhóm khách hàng chất lượng có số lượng cao ví dụ như: Champions, Loyal, Potential Loyalist
# - Một số nhóm khách hàng khác cần được tập trung quan tâm nhằm giảm số lượng ở những nhóm như: At Risk, Hibernating customers, Lost customers. Đặc biệt là nhóm khách hàng At Risk vì doanh thu của nhóm này mang lại rất cao
# - Ở tất cả các customer segment: channel có số lượng sử dụng nhiều nhất là Consumer đến Corporate cuối cùng là Home Office
# - Ship mode được sử dụng nhiều nhất là Standard Class và ít được sử dụng nhất là Same Day
# - Loại sản phẩm được nhiều người mua nhất là office supplies
# - Số lượng đơn hàng bị trả lại là không đáng kể ở tất cả customer segment

# %% [markdown]
# # Task 7: Which index should Marketing and Sales teams focus on?

# %%
df_product_unitprice = df[['Product ID', 'Unit Price']]
df_product_unitprice_sorted = df_product_unitprice.groupby('Product ID')['Unit Price'].max().reset_index().sort_values('Unit Price', ascending = False)
df_product_unitprice_sorted
# Out:
#            Product ID  Unit Price
# 1642  TEC-MA-10002412   4074.9264
# 1669  TEC-MA-10004125   2959.9926
# 1619  TEC-MA-10000418   2219.9926
# 1614  TEC-CO-10004722   1819.9948
# 1420  OFF-SU-10000151   1572.0288
# ...               ...         ...
# 907   OFF-FA-10000611      0.7696
# 905   OFF-FA-10000490      0.6572
# 911   OFF-FA-10000840      0.6042
# 1568  TEC-AC-10003709      0.5544
# 1559  TEC-AC-10003433      0.5445
#
# [1862 rows x 2 columns]

# %%
sns.histplot(x = 'Unit Price', data = df_product_unitprice_sorted, bins = 20)
plt.show()

# %%
df_product_unitprice_sorted.describe()
# Out:
#        Unit Price
# count  1862.00000
# mean     60.60775
# std     172.43179
# min       0.54450
# 25%       3.47360
# 50%      12.86040
# 75%      58.04865
# max    4074.92640

# %% [markdown]
# - Công ty có rất nhiều sản phẩm nhưng phần lớn sản phẩm có giá thành rẻ dễ tiếp cận
# - Nên tập trung vào chỉ số R và F thay vì M
